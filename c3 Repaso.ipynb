# %%
# Objetivo: "Python es un lenguaje de programación moderno"

cadena_1  = "moderno"
cadena_2  = "Python"
cadena_3  = "es un lenguaje"
cadena_4  = "de programación"

cadena=  cadena_2 + " " + cadena_3 + " " + cadena_4+" " + cadena_1 + "."
print(cadena)

# %%
cadena = "acitametaM" ,"5.8" ,"otipeP ordeP"
#revetir toda la cadena
print(cadena)
cadena_volteada = cadena[::-1]
print(cadena_volteada)
nombre = cadena_volteada[0][::-1]
nota = cadena_volteada[1]
materia = cadena_volteada[2][::-1]
print(f"{nombre} tiene una nota de {nota} en {materia}")

# %% [markdown]
# ![Imagen1.png](data:image/png;base64,...)

# %%
#slicing [inicio:fin:paso]

nombre_2= "Diego"
#print(nombre_2[0:7])

#nombre_1[1]= "y" #las cadenas de texto son inmutables
corte= nombre_2[0:2] + "y" + nombre_2[2:5]
#corte= nombre_2[0:2] + " " + nombre_2[3:5]
print(corte)

# %%
matriz = [[3, 5 ,1 ], [2,3,2], [5,1,2], [1,4,4]]
#1) Resolver manual

# suma_1 = matriz[0][0] + matriz[0][1] + matriz[0][2]
# suma_2 = matriz[1][0] + matriz[1][1] + matriz[1][2]
# suma_3 = matriz[2][0] + matriz[2][1] + matriz[2][2]
# suma_4 = matriz[3][0] + matriz[3][1] + matriz[3][2]
# print(suma_1, suma_2, suma_3, suma_4)
# matriz[0].append(suma_1)
# matriz[1].append(suma_2)
# matriz[2].append(suma_3)
# matriz[3].append(suma_4)

#2) Resolver con función sum

# suma_1=sum(matriz[0])
# suma_2=sum(matriz[1])
# suma_3=sum(matriz[2])
# suma_4=sum(matriz[3])

# matriz[0].append(suma_1)
# matriz[1].append(suma_2)
# matriz[2].append(suma_3)
# matriz[3].append(suma_4)

# matriz=[[1,5,1],[2,1,2],[3,0,1],[1,4,4]]
# matriz[0].append(sum(matriz[0]))
# matriz[1].append(sum(matriz[1]))
# matriz[2].append(sum(matriz[2]))
# matriz[3].append(sum(matriz[3]))
# print(matriz)
#3) ¿Como borramos un numero?

# matriz = [[1, 5, 1, 7], [2, 1, 2, 5], [3, 0, 1, 4], [1, 4, 4, 9]]

# matriz [0] = matriz[0][:3]
# matriz [1] = matriz[1][:3]
# matriz [2] = matriz[2][:3]
# matriz [3] = matriz[3][:3]
# print(matriz)
# Out:
# [[3, 5, 1, 9], [2, 3, 2, 7], [5, 1, 2, 8], [1, 4, 4, 9]]

# %%
#Repaso de operadores

# a = 9
# b = 3
# c = False
# d = True

# print (c and d)

# print (0 == "0" or 0 == float("0"))

# print (c or d)

#Si encuentra a (algo distinto a cero o false) imprime b
# print (True and b)

#Si a es false imprime lo que haya en b
# print (False or b)

#El ejemplo loco de la clase
a = 2
b = 3
print (a ** b / 3**a / a * b >= 15 or not (a%b**2) != 0)
# Out:
# False
# 2
# False
# False
# 1.3333333333333333
